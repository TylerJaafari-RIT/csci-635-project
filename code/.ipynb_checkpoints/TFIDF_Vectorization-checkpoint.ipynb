# %%
import pandas as pd
import numpy as np
import pickle as pickle
import sklearn.feature_extraction.text as skl_text
from sklearn.decomposition import PCA
import sklearn.svm as svm
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Loading data
train_set = pd.read_csv("../data/twitter_training.csv",names=["Tweet Id","Entity","Sentiment","Tweet Content"])
train_set
# Out:
#        Tweet Id       Entity Sentiment  \
# 0          2401  Borderlands  Positive
# 1          2401  Borderlands  Positive
# 2          2401  Borderlands  Positive
# 3          2401  Borderlands  Positive
# 4          2401  Borderlands  Positive
# ...         ...          ...       ...
# 74677      9200       Nvidia  Positive
# 74678      9200       Nvidia  Positive
# 74679      9200       Nvidia  Positive
# 74680      9200       Nvidia  Positive
# 74681      9200       Nvidia  Positive
#
#                                            Tweet Content
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
# Cleaning data
## Remove rows with missing values
hasnan=train_set.isna().any(axis=1)
for i in hasnan.index:
    if hasnan[i]:
        print("dropped",i)
        train_set=train_set.drop(i)
# Out:
# dropped 61
# dropped 553
# dropped 589
# dropped 745
# dropped 1105
# dropped 1106
# dropped 2295
# dropped 2296
# dropped 2297
# dropped 2359
# dropped 2413
# dropped 2473
# dropped 2474
# dropped 2929
# dropped 2983
# dropped 2997
# dropped 2998
# dropped 2999
# dropped 3061
# dropped 3097
# dropped 3243
# dropped 3244
# dropped 3245
# dropped 3337
# dropped 3457
# dropped 3697
# dropped 3835
# dropped 3836
# dropped 3939
# dropped 3940
# dropped 3941
# dropped 3967
# dropped 4233
# dropped 4234
# dropped 4235
# dropped 4237
# dropped 4413
# dropped 4414
# dropped 4415
# dropped 4755
# dropped 4756
# dropped 4757
# dropped 4869
# dropped 4870
# dropped 4871
# dropped 4899
# dropped 4900
# dropped 4901
# dropped 5421
# dropped 5422
# dropped 5423
# dropped 5521
# dropped 5559
# dropped 5560
# dropped 5561
# dropped 5731
# dropped 5973
# dropped 5974
# dropped 5975
# dropped 6015
# dropped 6016
# dropped 6017
# dropped 6067
# dropped 6068
# dropped 6081
# dropped 6082
# dropped 6083
# dropped 6585
# dropped 6586
# dropped 6587
# dropped 6699
# dropped 6700
# dropped 6701
# dropped 6861
# dropped 6862
# dropped 6863
# dropped 6903
# dropped 6904
# dropped 6905
# dropped 7051
# dropped 7305
# dropped 7306
# dropped 7307
# dropped 7669
# dropped 7809
# dropped 7810
# dropped 7811
# dropped 8407
# dropped 8691
# dropped 8692
# dropped 8693
# dropped 8877
# dropped 8878
# dropped 8879
# dropped 9013
# dropped 9253
# dropped 9254
# dropped 9453
# dropped 9454
# dropped 9455
# dropped 9495
# dropped 9496
# dropped 9497
# dropped 9561
# dropped 9562
# dropped 9563
# dropped 9703
# dropped 9931
# dropped 9932
# dropped 9987
# dropped 9988
# dropped 9989
# dropped 10035
# dropped 10036
# dropped 10037
# dropped 10143
# dropped 10144
# dropped 10145
# dropped 10255
# dropped 10263
# dropped 10264
# dropped 10265
# dropped 10419
# dropped 10420
# dropped 10421
# dropped 10435
# dropped 10485
# dropped 10486
# dropped 10487
# dropped 10551
# dropped 10552
# dropped 10553
# dropped 10677
# dropped 10678
# dropped 10679
# dropped 10825
# dropped 11325
# dropped 11326
# dropped 11327
# dropped 11335
# dropped 11463
# dropped 11464
# dropped 11465
# dropped 11547
# dropped 11548
# dropped 11549
# dropped 11557
# dropped 11558
# dropped 12169
# dropped 12331
# dropped 12487
# dropped 12561
# dropped 12562
# dropped 12563
# dropped 13249
# dropped 13441
# dropped 13921
# dropped 14492
# dropped 14545
# dropped 14546
# dropped 14557
# dropped 16225
# dropped 16429
# dropped 16483
# dropped 16593
# dropped 16594
# dropped 16595
# dropped 16807
# dropped 16903
# dropped 17107
# dropped 17373
# dropped 17374
# dropped 17375
# dropped 17623
# dropped 17667
# dropped 17668
# dropped 17669
# dropped 18127
# dropped 18151
# dropped 18242
# dropped 18301
# dropped 19177
# dropped 19381
# dropped 20463
# dropped 20464
# dropped 20465
# dropped 20623
# dropped 20624
# dropped 21079
# dropped 21265
# dropped 21799
# dropped 21901
# dropped 22035
# dropped 22036
# dropped 22037
# dropped 22119
# dropped 22120
# dropped 22121
# dropped 22399
# dropped 22489
# dropped 22555
# dropped 22575
# dropped 22576
# dropped 22577
# dropped 22705
# dropped 23079
# dropped 23080
# dropped 23081
# dropped 23349
# dropped 23350
# dropped 23351
# dropped 23523
# dropped 23524
# dropped 23525
# dropped 23541
# dropped 23542
# dropped 23543
# dropped 23599
# dropped 23707
# dropped 23708
# dropped 24067
# dropped 24343
# dropped 24631
# dropped 24632
# dropped 25147
# dropped 25148
# dropped 25233
# dropped 25234
# dropped 25235
# dropped 25239
# dropped 25240
# dropped 25241
# dropped 25809
# dropped 25810
# dropped 25811
# dropped 26551
# dropped 27087
# dropped 27088
# dropped 27089
# dropped 27705
# dropped 27706
# dropped 27707
# dropped 27927
# dropped 27928
# dropped 27929
# dropped 28015
# dropped 28077
# dropped 28078
# dropped 28079
# dropped 28135
# dropped 28227
# dropped 28228
# dropped 28229
# dropped 28279
# dropped 28353
# dropped 28354
# dropped 28355
# dropped 28975
# dropped 29847
# dropped 29848
# dropped 29849
# dropped 29983
# dropped 30255
# dropped 30256
# dropped 30257
# dropped 30331
# dropped 30721
# dropped 30729
# dropped 30730
# dropped 30731
# dropped 31791
# dropped 31792
# dropped 31793
# dropped 32319
# dropped 32320
# dropped 32321
# dropped 32565
# dropped 32566
# dropped 32567
# dropped 32577
# dropped 32578
# dropped 32579
# dropped 33231
# dropped 33232
# dropped 33233
# dropped 33291
# dropped 33292
# dropped 33293
# dropped 33343
# dropped 33405
# dropped 33406
# dropped 33407
# dropped 33417
# dropped 33418
# dropped 33419
# dropped 33445
# dropped 33879
# dropped 33880
# dropped 33881
# dropped 34149
# dropped 34150
# dropped 34151
# dropped 34333
# dropped 34411
# dropped 34845
# dropped 34846
# dropped 34847
# dropped 35031
# dropped 35032
# dropped 35033
# dropped 35169
# dropped 35170
# dropped 35171
# dropped 35541
# dropped 35542
# dropped 35543
# dropped 35671
# dropped 35685
# dropped 35686
# dropped 35687
# dropped 35907
# dropped 35908
# dropped 35909
# dropped 35967
# dropped 35968
# dropped 35969
# dropped 36183
# dropped 36184
# dropped 36185
# dropped 36241
# dropped 36307
# dropped 36567
# dropped 36568
# dropped 36569
# dropped 36903
# dropped 36904
# dropped 36905
# dropped 36927
# dropped 36928
# dropped 36929
# dropped 37083
# dropped 37084
# dropped 37085
# dropped 37215
# dropped 37216
# dropped 37217
# dropped 37483
# dropped 37747
# dropped 37969
# dropped 37999
# dropped 38499
# dropped 38500
# dropped 38501
# dropped 38593
# dropped 38635
# dropped 39027
# dropped 39028
# dropped 39029
# dropped 39669
# dropped 39670
# dropped 39671
# dropped 39897
# dropped 39898
# dropped 39899
# dropped 40125
# dropped 40126
# dropped 40127
# dropped 40251
# dropped 40252
# dropped 40253
# dropped 40345
# dropped 40357
# dropped 40377
# dropped 40378
# dropped 40379
# dropped 40809
# dropped 40810
# dropped 40811
# dropped 41367
# dropped 41368
# dropped 41369
# dropped 41545
# dropped 41805
# dropped 41806
# dropped 41807
# dropped 41811
# dropped 41812
# dropped 41813
# dropped 42165
# dropped 42166
# dropped 42167
# dropped 42225
# dropped 42226
# dropped 42227
# dropped 42351
# dropped 42352
# dropped 42353
# dropped 42517
# dropped 42518
# dropped 42603
# dropped 42604
# dropped 42605
# dropped 42813
# dropped 42814
# dropped 42815
# dropped 42867
# dropped 42868
# dropped 42869
# dropped 42969
# dropped 42970
# dropped 42971
# dropped 43407
# dropped 43408
# dropped 43409
# dropped 43447
# dropped 43537
# dropped 43633
# dropped 43683
# dropped 43684
# dropped 43685
# dropped 43747
# dropped 43777
# dropped 43929
# dropped 43930
# dropped 43931
# dropped 43965
# dropped 43966
# dropped 43967
# dropped 44449
# dropped 44649
# dropped 44650
# dropped 44651
# dropped 44857
# dropped 45061
# dropped 45133
# dropped 45403
# dropped 45537
# dropped 45538
# dropped 45539
# dropped 45711
# dropped 45712
# dropped 45713
# dropped 46071
# dropped 46072
# dropped 46073
# dropped 47019
# dropped 47020
# dropped 47021
# dropped 47431
# dropped 47599
# dropped 47803
# dropped 48043
# dropped 48081
# dropped 48082
# dropped 48083
# dropped 48253
# dropped 48343
# dropped 48573
# dropped 48574
# dropped 48575
# dropped 48753
# dropped 48754
# dropped 48755
# dropped 48949
# dropped 48950
# dropped 49489
# dropped 50181
# dropped 50182
# dropped 50183
# dropped 50515
# dropped 50631
# dropped 50632
# dropped 50633
# dropped 50643
# dropped 50644
# dropped 50645
# dropped 50745
# dropped 50746
# dropped 50747
# dropped 51453
# dropped 51454
# dropped 51455
# dropped 51853
# dropped 52249
# dropped 52855
# dropped 52977
# dropped 52978
# dropped 52979
# dropped 53121
# dropped 53122
# dropped 53123
# dropped 53503
# dropped 53859
# dropped 53860
# dropped 53861
# dropped 53899
# dropped 54045
# dropped 54046
# dropped 54047
# dropped 54111
# dropped 54112
# dropped 54113
# dropped 54739
# dropped 55035
# dropped 55036
# dropped 55037
# dropped 55497
# dropped 55498
# dropped 55499
# dropped 55681
# dropped 56035
# dropped 56043
# dropped 56044
# dropped 56045
# dropped 56077
# dropped 56619
# dropped 56620
# dropped 56621
# dropped 56683
# dropped 56733
# dropped 56734
# dropped 56735
# dropped 56739
# dropped 56740
# dropped 56741
# dropped 56907
# dropped 56908
# dropped 56909
# dropped 57183
# dropped 57184
# dropped 57185
# dropped 57325
# dropped 57355
# dropped 57681
# dropped 57682
# dropped 57683
# dropped 57795
# dropped 57796
# dropped 57797
# dropped 57837
# dropped 57838
# dropped 57839
# dropped 58105
# dropped 58161
# dropped 58162
# dropped 58163
# dropped 58731
# dropped 58732
# dropped 58733
# dropped 59043
# dropped 59044
# dropped 59045
# dropped 59125
# dropped 60356
# dropped 61081
# dropped 61165
# dropped 62007
# dropped 62008
# dropped 62009
# dropped 62025
# dropped 62026
# dropped 62027
# dropped 62371
# dropped 62372
# dropped 62809
# dropped 63105
# dropped 63106
# dropped 63107
# dropped 63445
# dropped 63591
# dropped 63592
# dropped 63593
# dropped 63639
# dropped 63640
# dropped 63641
# dropped 63769
# dropped 63933
# dropped 63934
# dropped 63935
# dropped 63969
# dropped 63970
# dropped 63971
# dropped 64167
# dropped 64168
# dropped 64169
# dropped 64569
# dropped 64570
# dropped 64571
# dropped 65779
# dropped 66457
# dropped 67375
# dropped 67681
# dropped 68067
# dropped 68068
# dropped 68069
# dropped 68169
# dropped 68170
# dropped 68171
# dropped 68367
# dropped 68368
# dropped 68369
# dropped 68389
# dropped 68451
# dropped 68452
# dropped 68453
# dropped 68679
# dropped 68680
# dropped 68681
# dropped 68901
# dropped 68902
# dropped 68903
# dropped 69093
# dropped 69094
# dropped 69095
# dropped 69337
# dropped 69405
# dropped 69406
# dropped 69407
# dropped 69475
# dropped 69495
# dropped 69496
# dropped 69497
# dropped 69571
# dropped 69613
# dropped 69631
# dropped 69663
# dropped 69664
# dropped 69665
# dropped 69795
# dropped 69796
# dropped 69797
# dropped 69951
# dropped 69952
# dropped 69953
# dropped 70317
# dropped 70318
# dropped 70319
# dropped 70371
# dropped 70372
# dropped 70373
# dropped 70665
# dropped 70666
# dropped 70667
# dropped 71365
# dropped 71541
# dropped 71542
# dropped 71543
# dropped 71929
# dropped 71961
# dropped 71962
# dropped 71963
# dropped 72091
# dropped 72092
# dropped 72321
# dropped 72322
# dropped 72323
# dropped 72369
# dropped 72370
# dropped 72371
# dropped 72885
# dropped 72886
# dropped 72887
# dropped 72957
# dropped 72958
# dropped 72959
# dropped 73021
# dropped 73069
# dropped 73233
# dropped 73234
# dropped 73235
# dropped 73243
# dropped 73387
# dropped 73521
# dropped 73522
# dropped 73523
# dropped 73657
# dropped 73761
# dropped 73762
# dropped 73763
# dropped 73855
# dropped 73971
# dropped 73972
# dropped 73973
# dropped 74421
# dropped 74422
# dropped 74423

# %%
# Fitting tf-idf vectorizer
tfidf_vec = skl_text.TfidfVectorizer(max_features=200)
tfidf_matrix = tfidf_vec.fit_transform(train_set["Tweet Content"])
tfidf_matrix.shape
# Out:
# (73996, 200)

# %%
# Dimensionality reduction
arr = [np.sum(tfidf_matrix[:,i]) for i in tqdm(range(tfidf_matrix.shape[1]))]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 160.96it/s]

# %%
#arr2 = np.array([arr,train_set["Tweet Id"].to_numpy()]).T

# %%
#arr2.shape

# %%
plt.scatter(range(tfidf_matrix.shape[1]),arr)

# %%
names = tfidf_vec.get_feature_names_out()
candidates = [[],[]]
cutoff = 500
for i in tqdm(range(len(arr))):
    if arr[i] > cutoff:
        candidates[0].append(names[i])
        candidates[1].append(arr[i])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 1034353.64it/s]

# %%
figure = plt.figure(figsize=[5,0.2*len(candidates[1])])
plt.barh(candidates[0],candidates[1])
#figure.show()
# Out:
# <BarContainer object of 146 artists>

# %%
names
# Out:
# array(['10', '2020', 'about', 'actually', 'after', 'again', 'all', 'also',
#        'always', 'am', 'amazing', 'amazon', 'an', 'and', 'any', 'are',
#        'as', 'at', 'back', 'bad', 'ban', 'battlefield', 'be', 'because',
#        'been', 'being', 'best', 'black', 'borderlands', 'but', 'by',
#        'call', 'can', 'co', 'com', 'damn', 'day', 'dead', 'depot', 'did',
#        'do', 'don', 'duty', 'eamaddennfl', 'even', 'ever', 'every',
#        'everyone', 'facebook', 'fifa', 'first', 'fix', 'for', 'fortnite',
#        'from', 'fuck', 'fucking', 'fun', 'game', 'games', 'get',
#        'getting', 'go', 'going', 'good', 'google', 'got', 'great', 'gta',
#        'guys', 'had', 'happy', 'has', 'have', 'he', 'help', 'here', 'his',
#        'home', 'how', 'https', 'if', 'in', 'into', 'is', 'it', 'its',
#        'johnson', 'just', 'know', 'last', 'league', 'legends', 'like',
#        'live', 'looks', 'love', 'made', 'make', 'man', 'me', 'microsoft',
#        'more', 'most', 'much', 'my', 'nba2k', 'never', 'new', 'news',
#        'next', 'no', 'not', 'now', 'nvidia', 'of', 'off', 'on', 'one',
#        'only', 'or', 'our', 'out', 'over', 'overwatch', 'people', 'pic',
#        'play', 'played', 'player', 'playing', 'please', 'ps5', 'pubg',
#        'rainbow6game', 're', 'really', 'red', 'redemption', 'rhandlerr',
#        'right', 'say', 'see', 'series', 'shit', 'so', 'some', 'still',
#        'stop', 'team', 'than', 'thank', 'thanks', 'that', 'the', 'their',
#        'them', 'then', 'there', 'these', 'they', 'think', 'this', 'time',
#        'to', 'today', 'too', 'tv', 'twitch', 'twitter', 'unk', 'up', 'us',
#        've', 'verizon', 'very', 'video', 'wait', 'want', 'was', 'watch',
#        'we', 'well', 'what', 'when', 'who', 'why', 'will', 'with', 'won',
#        'work', 'world', 'would', 'xbox', 'year', 'years', 'you', 'your',
#        'youtu', 'youtube'], dtype=object)

# %%
SVC = svm.LinearSVC()
SVC.fit(

# %%
d = {}
for s in train_set["Entity"]:
    if s not in d:
        d[s] = 0
    d[s] += 1

# %%
d
# Out:
# {'Borderlands': 2280,
#  'CallOfDutyBlackopsColdWar': 2343,
#  'Amazon': 2276,
#  'Overwatch': 2316,
#  'Xbox(Xseries)': 2283,
#  'NBA2K': 2343,
#  'Dota2': 2359,
#  'PlayStation5(PS5)': 2291,
#  'WorldOfCraft': 2357,
#  'CS-GO': 2284,
#  'Google': 2274,
#  'AssassinsCreed': 2234,
#  'ApexLegends': 2353,
#  'LeagueOfLegends': 2377,
#  'Fortnite': 2249,
#  'Microsoft': 2361,
#  'Hearthstone': 2286,
#  'Battlefield': 2316,
#  'PlayerUnknownsBattlegrounds(PUBG)': 2234,
#  'Verizon': 2365,
#  'HomeDepot': 2292,
#  'FIFA': 2324,
#  'RedDeadRedemption(RDR)': 2249,
#  'CallOfDuty': 2376,
#  'TomClancysRainbowSix': 2364,
#  'Facebook': 2362,
#  'GrandTheftAuto(GTA)': 2293,
#  'MaddenNFL': 2377,
#  'johnson&johnson': 2324,
#  'Cyberpunk2077': 2262,
#  'TomClancysGhostRecon': 2321,
#  'Nvidia': 2271}
